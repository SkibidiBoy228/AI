# %%
from collections import Counter

votes = [
    "apple",
    "banana",
    "apple",
    "orange",
    "banana",
    "apple",
    "apple",
    "apple",
    "orange"
]

counter = Counter(votes)

leader = counter.most_common(1)[0]
top3 = counter.most_common(3)

print(counter)
print("Leader:", leader)
print("Top 3:", top3)
# Out:
# Counter({'apple': 5, 'banana': 2, 'orange': 2})
# Leader: ('apple', 5)
# Top 3: [('apple', 5), ('banana', 2), ('orange', 2)]

# %% [markdown]
# | Фрукт | Кількість |
# |--------|-----------|
# | apple | 5 |
# | banana | 2 |
# | orange | 2 |
#
# ### Топ-3
#
# | Місце | Фрукт | Кількість |
# |--------|--------|-----------|
# | 1 | apple | 5 |
# | 2 | banana | 2 |
# | 3 | orange | 2 |
